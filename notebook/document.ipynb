# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is the main text for RAG",
    metadata = {
        "source":"example.txt",
        "pages": 1,
        "author": "Arpit Dubey",
        "data_created": "2026-07-25"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Arpit Dubey', 'data_created': '2026-07-25'}, page_content='This is the main text for RAG')

# %%
# Create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok = True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
# TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Directory Loader
from langchain_community.document_loaders import DirectoryLoader

# load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # Pattern to match files  
    loader_cls= TextLoader, # loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", # Pattern to match files  
    loader_cls= PyMuPDFLoader, # loader class to use
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-22T09:40:44+00:00', 'source': '..\\data\\pdf\\Resume__Arpit_Dubey.pdf', 'file_path': '..\\data\\pdf\\Resume__Arpit_Dubey.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-06-22T09:40:44+00:00', 'trapped': '', 'modDate': 'D:20260622094044Z', 'creationDate': 'D:20260622094044Z', 'page': 0}, page_content='Arpit Dubey\nEmail: dubey1033arpit@gmail.com\nLinkedIn\nPhone: +91-9560818644\nGitHub\nEducation\nIndian Institute of Information Technology, Lucknow\nLucknow, India\nBachelor of Technology in Computer Science and Business | CGPA: 8.76/10\nJuly 2022 - July 2026\nDelhi Public School, Greater Noida\nGreater Noida , India\nCBSE Class XII - 95%\nFeb 2020 - June 2022\nExperience\nAmazon\nGurugram, India\nSoftware Development Engineer Intern\nJuly 2025 – Dec 2025\n• Built a full-stack Payments Portal using React and Redux for invoice and dispute management, cutting resolution time from 3-4\nweeks to 2-3 days and improving operational visibility for internal ﬁnance teams.\n• Provisioned and automated AWS OpenSearch using AWS CDK (IaC) to deliver scalable, low-latency search over invoice and\ndispute records.\n• Engineered robust Service Access Object (SAO) components in Java and Spring Boot with network error handling and retry\nmechanisms to reliably fetch, aggregate, and normalize data from multiple downstream services.\n• Migrated a production service to AWS Graviton using AWS CDK, updated IaC and CI/CD pipelines, and reduced instance costs\nby ∼30% while improving CPU performance by ∼28%.\n• Authored unit and integration tests with JUnit and Mockito, achieving high coverage on critical payment workﬂows to ensure\nproduction reliability and reduce regression risk during deployments.\n• Tech Stack: AWS (CDK, OpenSearch, CodePipeline, CloudWatch), Java, Spring Boot, REST APIs, JUnit, Mockito, React, Redux,\nGit, CI/CD\nTechnical Skills\n• Languages: C++, Python, Java, JavaScript\n• Frameworks & Libraries: Django, Flask, Django REST Framework, React, Redux, Tailwind CSS, HTML/CSS\n• Databases: SQL, PostgreSQL, MySQL\n• Cloud & DevOps: AWS (CDK, CodePipeline, CloudWatch, OpenSearch), GitHub Actions, Docker\n• Developer Tools: Linux, Git, GitHub, Postman, VS Code, IntelliJ\n• Academic Coursework: Data Structures and Algorithms, Database Management Systems, Object Oriented Programming,\nOperating Systems, Web Development, Software Engineering\nProjects\n• PolicyAware LLM Orchestrator\n| Live Demo\n| Python, Django Ninja, LangGraph, Gemini, PostgreSQL, Permit.io, Render\n◦\nDesigned and deployed a multi-agent AI system using LangGraph and Google Gemini for natural language document\nworkﬂows, enforcing Permit.io RBAC on every AI tool call to prevent unauthorized data access across concurrent users.\n◦\nEngineered a LangGraph Supervisor architecture that enables specialized sub-agents to collaboratively address diverse user\nintents, enhanced by PostgresSaver for persistent conversation memory across sessions.\n◦\nHardened the production Django Ninja backend with per-user rate limiting, input validation, and JWT-bound session isolation\nto ensure system resilience and prevent API abuse on a live, multi-user deployment.\n• Django Blog CMS\n| Python, Django, SQLite, HTML/CSS, Bootstrap, REST APIs, GitHub Actions, Docker\n◦\nDeveloped a secure Django blog with end-to-end CRUD operations and ownership-based authorization to safeguard user\ndata and sessions.\n◦\nImplemented secure authentication with SMTP-based password resets and dynamic user proﬁles featuring custom media\nhandling and ﬁle processing.\n◦\nConﬁgured GitHub Actions to automate Python linting, verify database migrations, and execute weekly security scans.\nAchievements\n• Rated Specialist (max-rating : 1445) on Codeforces Handle: thomas 5791\n• Rated 4 star (max-rating : 1836) on Codechef. Handle: cppco ...
